# %%
import pandas as pd

# %%
train_df, test_df = pd.read_csv('~/Tweet-Sentiment-Extraction-Data/train.csv').set_index('textID'),\
                    pd.read_csv('~/Tweet-Sentiment-Extraction-Data/test.csv').set_index('textID')

# %%
all_df = pd.concat([train_df, test_df], keys=['train', 'test'], 
                   names=['dataset'])\
                   .reset_index('dataset')

# %%
all_df
# Out:
#            dataset                                               text  \
# textID
# cb774db0d1   train                I`d have responded, if I were going
# 549e992a42   train      Sooo SAD I will miss you here in San Diego!!!
# 088c60f138   train                          my boss is bullying me...
# 9642c003ef   train                     what interview! leave me alone
# 358bd9e861   train   Sons of ****, why couldn`t they put them on t...
# ...            ...                                                ...
# e5f0e6ef4b    test  its at 3 am, im very tired but i can`t sleep  ...
# 416863ce47    test  All alone in this old house again.  Thanks for...
# 6332da480c    test   I know what you mean. My little dog is sinkin...
# df1baec676    test  _sutra what is your next youtube video gonna b...
# 469e15c5a8    test   http://twitpic.com/4woj2 - omgssh  ang cute n...
#
#                                   selected_text sentiment
# textID
# cb774db0d1  I`d have responded, if I were going   neutral
# 549e992a42                             Sooo SAD  negative
# 088c60f138                          bullying me  negative
# 9642c003ef                       leave me alone  negative
# 358bd9e861                        Sons of ****,  negative
# ...                                         ...       ...
# e5f0e6ef4b                                  NaN  negative
# 416863ce47                                  NaN  positive
# 6332da480c                                  NaN  negative
# df1baec676                                  NaN  positive
# 469e15c5a8                                  NaN  positive
#
# [31015 rows x 4 columns]
